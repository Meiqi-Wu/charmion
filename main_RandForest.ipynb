# %%
# !python --version
# Out:
# Python 3.8.3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV, StratifiedKFold, KFold
from sklearn.metrics import log_loss, precision_score, recall_score, f1_score
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA

import time
from concurrent.futures import ThreadPoolExecutor
from concurrent.futures import wait, ALL_COMPLETED, as_completed
from tqdm import tqdm
import joblib
import warnings
warnings.filterwarnings('ignore')
# %load_ext autoreload
# %autoreload 2

# %%
data_dir = './DATA/lish-moa/'

# %% [markdown]
# ***
# # Table of Contents
# 1. Load the dataset
# 2. Preprocessing
# 3. Models : Binary Relevance (Random Forest)
# ***

# %% [markdown]
# ## Load the dataset

# %%
X = pd.read_csv(data_dir+'train_features.csv', index_col='sig_id')
y = pd.read_csv(data_dir+'train_targets_scored.csv', index_col='sig_id')

# %% [markdown]
# ## Preprocessing

# %%
# One-hot encoding for cp_type and cp_dose
X['cp_type'].replace({'trt_cp':1., 'ctl_vehicle':0.}, inplace=True)
X['cp_dose'].replace({'D1':1., 'D2':0.}, inplace=True)

# split into training set and test set
SEED = 123
np.random.seed(SEED)

ids = X.index.values.copy()
np.random.shuffle(ids)

train_perc, test_perc = 0.85, 0.15
train_id = ids[:round(len(ids)*train_perc)]
test_id = ids[round(len(ids)*train_perc):]

X_train = X.loc[train_id]
X_test = X.loc[test_id]

y_train = y.loc[train_id]
y_test = y.loc[test_id]

# normalize the data
scaler = StandardScaler()
X_train_norm = pd.DataFrame(scaler.fit_transform(X_train))
X_train_norm.columns = X_train.columns
X_train_norm.index = X_train.index

X_test_norm = pd.DataFrame(scaler.transform(X_test))
X_test_norm.columns = X_test.columns
X_test_norm.index = X_test.index

# %% [markdown]
# ## Model

# %%
# 
pca = PCA(n_components=500)
X_train_pca = pd.DataFrame(pca.fit_transform(X_train_norm))
X_train_pca.index = X_train.index

X_test_pca = pd.DataFrame(pca.transform(X_test_norm))
X_test_pca.index = X_test.index

# %%
weight_ratio = 0.73
n_estimators = 120
max_depth = 4
min_samples_leaf = 1

model_dic_rf = {}
X = X_train_pca.values
for col_name, y in tqdm(y_train.iteritems()):
    # class_weight for each target column
    class_weight = {0:1, 1:min(round(len(y)/sum(y)-1)*weight_ratio, 8000)} 
    
#     pca = PCA(n_components = n_components)
    rfc = RandomForestClassifier( n_estimators = n_estimators,
                                  max_depth = max_depth,
                                  class_weight = class_weight,
                                  min_samples_leaf = min_samples_leaf,
                                  n_jobs = -1,
                                  random_state=100);
#     pipe = Pipeline(steps=[('pca',pca), ('rfc', rfc)])
    rfc.fit(X, y);
    model_dic_rf[col_name] = rfc

# inference
y_train_predict = pd.DataFrame([], columns=y_train.columns)
y_test_predict = pd.DataFrame([], columns=y_train.columns)
X = X_train_pca.values
X2 = X_test_pca.values
for i, rfc in tqdm(model_dic_rf.items()):
    y_train_predict[i] = rfc.predict(X)
    y_test_predict[i] = rfc.predict(X2)
# Out:
# 206it [25:26,  7.41s/it]
# 100%|██████████| 206/206 [23:57<00:00,  6.98s/it]

# %%
# binary relevance
# print('n_components:', n_components)
print('weight_ratio: ', weight_ratio,' n_estimators:',n_estimators,' max_depth: ', max_depth, ' max_features:',max_features, ' min_samples_leaf:',min_samples_leaf)
print('Precision: ')
print(precision_score(y_train.values.reshape(-1, 1), y_train_predict.values.reshape(-1, 1)))
print('Recall: ')
print(recall_score(y_train.values.reshape(-1, 1), y_train_predict.values.reshape(-1, 1)))
print('F1: ')
print(f1_score(y_train.values.reshape(-1, 1), y_train_predict.values.reshape(-1, 1)))
print()
print('Precision: ')
print(precision_score(y_test.values.reshape(-1, 1), y_test_predict.values.reshape(-1, 1)))
print('Recall: ')
print(recall_score(y_test.values.reshape(-1, 1), y_test_predict.values.reshape(-1, 1)))
print('F1: ')
print(f1_score(y_test.values.reshape(-1, 1), y_test_predict.values.reshape(-1, 1)))
print()
print(y_train.sum().sum())
print(y_train_predict.sum().sum())
print()
print(y_test.sum().sum())
print(y_test_predict.sum().sum())
# Out:
# weight_ratio:  0.73  n_estimators: 120  max_depth:  4  max_features: 30  min_samples_leaf: 1
# Precision:
# 0.8950437317784257
# Recall:
# 0.5576358809557077
# F1:
# 0.6871556473829201
#
# Precision:
# 0.7209302325581395
# Recall:
# 0.19604743083003953
# F1:
# 0.30826600372902424
#
# 14314
# 8918
#
# 2530
# 688

# %% [markdown]
# ### Grid search with cross-validatation

# %%
folds = 5

current = 0
start = 0
best_rfc = {}
best_params = {}
X = X_train.values
def search_model(i, col_name, y):
    global best_rfc
    global best_params
    global current
    global start
    
    start += 1
    start_time = time.process_time()
    print("Start " + str(start) + " ")

    ratio = round(len(y)/sum(y)-1)
    tuned_params = {
        'class_weight':[{0:1, 1:round(weight_ratio*ratio)} for weight_ratio in [0.71, 0.72, 0.73, 0.74, 0.75, 0.76]],
        'max_depth': [3,4,5,6,7],
        'max_features':[25, 30, 35]
    }
    rfc = RandomForestClassifier(n_jobs=-1, random_state = 100)


    skf = StratifiedKFold(n_splits=folds, shuffle = True, random_state = 200)
    search = GridSearchCV(estimator = rfc, param_grid=tuned_params,
                          cv = skf.split(X, y), scoring='neg_log_loss')
    search.fit(X, y)

    best_rfc[col_name] = search.best_estimator_
    best_params[col_name] = search.best_params_
    
    joblib.dump(best_rfc[col_name], f'./TrainedModels/RandForest/rf_{i}.joblib')
    current += 1
    print("--- Completed %s, %s, %.4f mins ---" % (current, col_name, (time.process_time() - start_time) / 60))
    
with ThreadPoolExecutor(max_workers=4) as t:
    futures = []
    for i, (col_name, y) in enumerate(y_train.iteritems()):
        futures.append(t.submit(search_model, i, col_name, y))

    for future in as_completed(futures):
        print(future.result())
        
# for i, (col_name, y) in tqdm(enumerate(y_train.iteritems())):
#     if i in [22, 34, 69, 81, 82, 121, 137, 141, 172]:
#         search_model(i, col_name, y);
too_skew = [22, 34, 69, 81, 82, 121, 137, 141, 172]
# Out:
# Start 1
# Start 2
# Start 3
# Start 4
# --- Completed 1, 5-alpha_reductase_inhibitor, 13.7320 mins ---
# Start 5
# None
# --- Completed 2, 11-beta-hsd1_inhibitor, 14.3008 mins ---
# Start 6
# None
# --- Completed 3, acat_inhibitor, 15.8760 mins ---
# Start 7
# None
# --- Completed 4, acetylcholine_receptor_agonist, 16.8310 mins ---
# Start 8
# None
# --- Completed 5, acetylcholinesterase_inhibitor, 15.4062 mins ---
# Start 9 None
#
# --- Completed 6, acetylcholine_receptor_antagonist, 16.3242 mins ---
# Start 10
# None
# --- Completed 7, adenosine_receptor_agonist, 16.0154 mins ---
# Start 11
# None
# --- Completed 8, adenosine_receptor_antagonist, 16.5768 mins ---
# Start 12
# None
# --- Completed 9, adenylyl_cyclase_activator, 14.5750 mins ---
# Start 13
# None
# --- Completed 10, adrenergic_receptor_agonist, 16.6154 mins ---
# Start 14 None
#
# --- Completed 11, adrenergic_receptor_antagonist, 16.5065 mins ---
# Start 15
# None
# --- Completed 12, akt_inhibitor, 16.6648 mins ---
# Start 16
# None
# --- Completed 13, aldehyde_dehydrogenase_inhibitor, 14.4854 mins ---
# Start 17
# None
# --- Completed 14, alk_inhibitor, 15.6253 mins ---
# Start 18 None
#
# --- Completed 15, ampk_activator, 15.8719 mins ---
# Start 19
# None
# --- Completed 16, analgesic, 15.2964 mins ---
# Start 20
# None
# --- Completed 17, androgen_receptor_agonist, 15.6906 mins ---
# Start 21
# None
# --- Completed 18, androgen_receptor_antagonist, 15.6125 mins ---
# Start 22
# None
# --- Completed 19, anesthetic_-_local, 16.3318 mins ---
# Start 23
# None
# --- Completed 20, angiogenesis_inhibitor, 16.4388 mins ---
# Start 24
# None
# --- Completed 21, angiotensin_receptor_antagonist, 16.0214 mins ---
# Start 25
# None
# --- Completed 22, anti-inflammatory, 15.8625 mins ---
# Start 26
# None
# --- Completed 23, antiarrhythmic, 14.7336 mins ---
# Start 27
# None
# --- Completed 24, antibiotic, 16.6010 mins ---
# Start 28 None
#
# --- Completed 25, anticonvulsant, 14.9273 mins ---
# Start 29
# None
# --- Completed 26, antifungal, 14.9974 mins ---
# Start 30
# None
# --- Completed 27, antihistamine, 15.4227 mins ---
# Start 31
# None
# --- Completed 28, antimalarial, 15.7922 mins ---
# Start 32
# None
# --- Completed 29, antioxidant, 15.7365 mins ---
# Start 33
# None
# --- Completed 30, antiprotozoal, 15.4107 mins ---
# Start 34
# None
# --- Completed 31, antiviral, 15.3651 mins ---
# Start 35 None
#
# --- Completed 32, apoptosis_stimulant, 16.6641 mins ---
# Start 36
# None
# --- Completed 33, aromatase_inhibitor, 16.4372 mins ---
# Start 37 None
#
# --- Completed 34, atm_kinase_inhibitor, 14.3612 mins ---
# Start 38 None
#
# --- Completed 35, atp-sensitive_potassium_channel_antagonist, 12.6260 mins ---
# Start 39 None
#
# --- Completed 36, atp_synthase_inhibitor, 14.6891 mins ---
# Start 40
# None
# --- Completed 37, atr_kinase_inhibitor, 13.7792 mins ---
# Start 41
# None
# --- Completed 38, atpase_inhibitor, 16.2060 mins ---
# Start 42 None
#
# --- Completed 39, aurora_kinase_inhibitor, 17.0536 mins ---
# Start 43
# None
# --- Completed 40, autotaxin_inhibitor, 15.6596 mins ---
# Start 44
# None
# --- Completed 41, bacterial_30s_ribosomal_subunit_inhibitor, 16.2466 mins ---
# Start 45
# None
# --- Completed 42, bacterial_50s_ribosomal_subunit_inhibitor, 16.2766 mins ---
# Start 46
# None
# --- Completed 43, bacterial_antifolate, 15.7510 mins ---
# Start 47
# None
# --- Completed 44, bacterial_cell_wall_synthesis_inhibitor, 16.8706 mins ---
# Start 48
# None
# --- Completed 45, bacterial_dna_gyrase_inhibitor, 15.9201 mins ---
# Start 49
# None
# --- Completed 46, bacterial_membrane_integrity_inhibitor, 14.3086 mins ---
# Start 50
# None
# --- Completed 47, bacterial_dna_inhibitor, 16.3724 mins ---
# Start 51 None
#
# --- Completed 48, bcl_inhibitor, 16.2771 mins ---
# Start 52
# None
# --- Completed 49, bcr-abl_inhibitor, 15.4990 mins ---
# Start 53 None
#
# --- Completed 50, beta_amyloid_inhibitor, 15.2807 mins ---
# Start 54
# None
# --- Completed 51, benzodiazepine_receptor_agonist, 17.0180 mins ---
# Start 55
# None
# --- Completed 52, bromodomain_inhibitor, 17.3523 mins ---
# Start 56
# None
# --- Completed 53, btk_inhibitor, 15.8549 mins ---
# Start 57
# None
# --- Completed 54, calcineurin_inhibitor, 15.1286 mins ---
# Start 58
# None
# --- Completed 55, calcium_channel_blocker, 16.7763 mins ---
# Start 59
# None
# --- Completed 56, cannabinoid_receptor_agonist, 16.2823 mins ---
# Start 60
# None
# --- Completed 57, cannabinoid_receptor_antagonist, 15.5948 mins ---
# Start 61
# None
# --- Completed 58, carbonic_anhydrase_inhibitor, 15.9805 mins ---
# Start 62
# None
# --- Completed 59, casein_kinase_inhibitor, 15.6081 mins ---
# Start 63
# None
# --- Completed 60, caspase_activator, 16.1315 mins ---
# Start 64
# None
# --- Completed 61, catechol_o_methyltransferase_inhibitor, 14.3943 mins ---
# Start 65
# None
# --- Completed 62, cc_chemokine_receptor_antagonist, 16.3156 mins ---
# Start 66 None
#
# --- Completed 63, cck_receptor_antagonist, 15.4370 mins ---
# Start 67
# None
# --- Completed 64, cdk_inhibitor, 16.7557 mins ---
# Start 68
# None
# --- Completed 65, chelating_agent, 16.2336 mins ---
# Start 69
# None
# --- Completed 66, chk_inhibitor, 14.9365 mins ---
# Start 70
# None
# --- Completed 67, chloride_channel_blocker, 16.1315 mins ---
# Start 71
# None
# --- Completed 68, cholesterol_inhibitor, 16.4141 mins ---
# Start 72
# None
# --- Completed 69, cholinergic_receptor_antagonist, 15.6953 mins ---
# Start 73 None
#
# --- Completed 70, coagulation_factor_inhibitor, 14.5089 mins ---
# Start 74
# None
# --- Completed 71, corticosteroid_agonist, 15.9135 mins ---
# Start 75
# None
# --- Completed 72, cytochrome_p450_inhibitor, 15.6281 mins ---
# Start 76
# None
# --- Completed 73, dihydrofolate_reductase_inhibitor, 15.5234 mins ---
# Start 77
# None
# --- Completed 74, cyclooxygenase_inhibitor, 17.4669 mins ---
# Start 78
# None
# --- Completed 75, dipeptidyl_peptidase_inhibitor, 15.7333 mins ---
# Start 79
# None
# --- Completed 76, diuretic, 14.4646 mins ---
# Start 80
# None
# --- Completed 77, dna_alkylating_agent, 16.4711 mins ---
# Start 81
# None
# --- Completed 78, dna_inhibitor, 17.3813 mins ---
# Start 82
# None
# --- Completed 79, dopamine_receptor_agonist, 17.2789 mins ---
# Start 83
# None
# --- Completed 80, dopamine_receptor_antagonist, 17.4927 mins ---
# Start 84
# None
# --- Completed 81, elastase_inhibitor, 14.7333 mins ---
# Start 85 None
#
# --- Completed 82, erbb2_inhibitor, 11.8586 mins ---
# Start 86
# None
# --- Completed 83, egfr_inhibitor, 18.5146 mins ---
# Start 87
# None
# --- Completed 84, estrogen_receptor_agonist, 16.5250 mins ---
# Start 88
# None
# --- Completed 85, farnesyltransferase_inhibitor, 14.8310 mins ---
# Start 89
# None
# --- Completed 86, estrogen_receptor_antagonist, 17.3909 mins ---
# Start 90
# None
# --- Completed 87, faah_inhibitor, 17.3070 mins ---
# Start 91
# None
# --- Completed 88, fatty_acid_receptor_agonist, 15.7531 mins ---
# Start 92
# None
# --- Completed 89, focal_adhesion_kinase_inhibitor, 14.7016 mins ---
# Start 93
# None
# --- Completed 90, fgfr_inhibitor, 16.6419 mins ---
# Start 94 None
#
# --- Completed 91, flt3_inhibitor, 17.3604 mins ---
# Start 95
# None
# --- Completed 92, free_radical_scavenger, 16.3096 mins ---
# Start 96
# None
# --- Completed 93, fungal_squalene_epoxidase_inhibitor, 17.0076 mins ---
# Start 97
# None
# --- Completed 94, gaba_receptor_agonist, 17.4016 mins ---
# Start 98
# None
# --- Completed 95, gaba_receptor_antagonist, 17.3833 mins ---
# Start 99 None
#
# --- Completed 96, gamma_secretase_inhibitor, 15.5484 mins ---
# Start 100
# None
# --- Completed 97, glutamate_inhibitor, 14.5167 mins ---
# Start 101
# None
# --- Completed 98, glucocorticoid_receptor_agonist, 16.8263 mins ---
# Start 102
# None
# --- Completed 99, glutamate_receptor_agonist, 16.6008 mins ---
# Start 103
# None
# --- Completed 100, glutamate_receptor_antagonist, 15.9497 mins ---
# Start 104
# None
# --- Completed 101, gonadotropin_receptor_agonist, 15.4065 mins ---
# Start 105
# None
# --- Completed 102, gsk_inhibitor, 16.4516 mins ---
# Start 106
# None
# --- Completed 103, hcv_inhibitor, 16.8826 mins ---
# Start 107
# None
# --- Completed 104, hdac_inhibitor, 15.6909 mins ---
# Start 108
# None
# --- Completed 105, histamine_receptor_agonist, 16.1458 mins ---
# Start 109
# None
# --- Completed 106, histamine_receptor_antagonist, 16.9503 mins ---
# Start 110
# None
# --- Completed 107, histone_lysine_demethylase_inhibitor, 16.2078 mins ---
# Start 111
# None
# --- Completed 108, histone_lysine_methyltransferase_inhibitor, 15.4224 mins ---
# Start 112
# None
# --- Completed 109, hiv_inhibitor, 15.9451 mins ---
# Start 113
# None
# --- Completed 110, hmgcr_inhibitor, 16.7297 mins ---
# Start 114
# None
# --- Completed 111, hsp_inhibitor, 17.0359 mins ---
# Start 115
# None
# --- Completed 112, igf-1_inhibitor, 16.4969 mins ---
# Start 116
# None
# --- Completed 113, ikk_inhibitor, 17.1609 mins ---
# Start 117
# None
# --- Completed 114, imidazoline_receptor_agonist, 16.7937 mins ---
# Start 118
# None
# --- Completed 115, immunosuppressant, 17.2672 mins ---
# Start 119
# None
# --- Completed 116, insulin_secretagogue, 15.0659 mins ---
# Start 120
# None
# --- Completed 117, insulin_sensitizer, 15.5487 mins ---
# Start 121
# None
# --- Completed 118, integrin_inhibitor, 15.6081 mins ---
# Start 122
# None
# --- Completed 119, jak_inhibitor, 16.4607 mins ---
# Start 123 None
#
# --- Completed 120, kit_inhibitor, 16.1107 mins ---
# Start 124 None
#
# --- Completed 121, laxative, 14.5802 mins ---
# Start 125
# None
# --- Completed 122, leukotriene_inhibitor, 15.0229 mins ---
# Start 126
# None
# --- Completed 123, leukotriene_receptor_antagonist, 16.6367 mins ---
# Start 127
# None
# --- Completed 124, lipase_inhibitor, 14.5432 mins ---
# Start 128
# None
# --- Completed 125, lipoxygenase_inhibitor, 15.8313 mins ---
# Start 129 None
#
# --- Completed 126, lxr_agonist, 14.8786 mins ---
# Start 130
# None
# --- Completed 127, mdm_inhibitor, 15.7362 mins ---
# Start 131
# None
# --- Completed 128, mek_inhibitor, 15.9461 mins ---
# Start 132
# None
# --- Completed 129, membrane_integrity_inhibitor, 16.1576 mins ---
# Start 133
# None
# --- Completed 130, mineralocorticoid_receptor_antagonist, 15.9161 mins ---
# Start 134
# None
# --- Completed 131, monoacylglycerol_lipase_inhibitor, 15.7484 mins ---
# Start 135
# None
# --- Completed 132, monoamine_oxidase_inhibitor, 15.5107 mins ---
# Start 136
# None
# --- Completed 133, monopolar_spindle_1_kinase_inhibitor, 14.6159 mins ---
# Start 137 None
#
# --- Completed 134, mtor_inhibitor, 16.3591 mins ---
# Start 138
# None
# --- Completed 135, mucolytic_agent, 16.5888 mins ---
# Start 139 None
#
# --- Completed 136, neuropeptide_receptor_antagonist, 15.2664 mins ---
# Start 140
# None
# --- Completed 137, nfkb_inhibitor, 16.9768 mins ---
# Start 141
# None
# --- Completed 138, nicotinic_receptor_agonist, 15.0898 mins ---
# Start 142 None
#
# --- Completed 139, nitric_oxide_donor, 16.7346 mins ---
# Start 143
# None
# --- Completed 140, nitric_oxide_production_inhibitor, 15.7440 mins ---
# Start 144
# None
# --- Completed 141, nitric_oxide_synthase_inhibitor, 16.2013 mins ---
# Start 145
# None
# --- Completed 142, norepinephrine_reuptake_inhibitor, 15.0987 mins ---
# Start 146
# None
# --- Completed 143, nrf2_activator, 15.3396 mins ---
# Start 147
# None
# --- Completed 144, opioid_receptor_agonist, 15.5044 mins ---
# Start 148
# None
# --- Completed 145, opioid_receptor_antagonist, 15.4544 mins ---
# Start 149
# None
# --- Completed 146, orexin_receptor_antagonist, 15.5536 mins ---
# Start 150 None
#
# --- Completed 147, p-glycoprotein_inhibitor, 15.3721 mins ---
# Start 151
# None
# --- Completed 148, p38_mapk_inhibitor, 16.4229 mins ---
# Start 152
# None
# --- Completed 149, parp_inhibitor, 15.7911 mins ---
# Start 153
# None
# --- Completed 150, pdgfr_inhibitor, 16.2078 mins ---
# Start 154
# None
# --- Completed 151, pdk_inhibitor, 15.3115 mins ---
# Start 155
# None
# --- Completed 152, phosphodiesterase_inhibitor, 16.6914 mins ---
# Start 156
# None
# --- Completed 153, phospholipase_inhibitor, 16.1320 mins ---
# Start 157 None
#
# --- Completed 154, pi3k_inhibitor, 17.1714 mins ---
# Start 158 None
#
# --- Completed 155, pkc_inhibitor, 16.0529 mins ---
# Start 159
# None
# --- Completed 156, potassium_channel_activator, 16.1503 mins ---
# Start 160
# None
# --- Completed 157, potassium_channel_antagonist, 16.2122 mins ---
# Start 161
# None
# --- Completed 158, ppar_receptor_agonist, 16.0622 mins ---
# Start 162
# None
# --- Completed 159, ppar_receptor_antagonist, 15.3523 mins ---
# Start 163
# None
# --- Completed 160, progesterone_receptor_agonist, 15.8474 mins ---
# Start 164
# None
# --- Completed 161, progesterone_receptor_antagonist, 15.0138 mins ---
# Start 165
# None
# --- Completed 162, prostaglandin_inhibitor, 15.5029 mins ---
# Start 166
# None
# --- Completed 163, prostanoid_receptor_antagonist, 16.4102 mins ---
# Start 167 None
#
# --- Completed 164, proteasome_inhibitor, 15.4292 mins ---
# Start 168
# None
# --- Completed 165, protein_kinase_inhibitor, 16.3010 mins ---
# Start 169
# None
# --- Completed 166, protein_phosphatase_inhibitor, 15.3005 mins ---
# Start 170
# None
# --- Completed 167, protein_synthesis_inhibitor, 16.2284 mins ---
# Start 171 None
#
# --- Completed 168, protein_tyrosine_kinase_inhibitor, 15.2414 mins ---
# Start 172
# None
# --- Completed 169, radiopaque_medium, 15.8521 mins ---
# Start 173
# None
# --- Completed 170, raf_inhibitor, 16.8818 mins ---
# Start 174
# None
# --- Completed 171, ras_gtpase_inhibitor, 15.1937 mins ---
# Start 175
# None
# --- Completed 172, retinoid_receptor_agonist, 16.2227 mins ---
# Start 176
# None
# --- Completed 173, retinoid_receptor_antagonist, 14.4167 mins ---
# Start 177
# None
# --- Completed 174, rho_associated_kinase_inhibitor, 15.3245 mins ---
# Start 178
# None
# --- Completed 175, ribonucleoside_reductase_inhibitor, 15.5021 mins ---
# Start 179 None
#
# --- Completed 176, rna_polymerase_inhibitor, 15.2917 mins ---
# Start 180
# None
# --- Completed 177, serotonin_receptor_agonist, 16.3125 mins ---
# Start 181 None
#
# --- Completed 178, serotonin_receptor_antagonist, 16.5372 mins ---
# Start 182
# None
# --- Completed 179, serotonin_reuptake_inhibitor, 16.2909 mins ---
# Start 183
# None
# --- Completed 180, sigma_receptor_agonist, 15.9333 mins ---
# Start 184
# None
# --- Completed 181, sigma_receptor_antagonist, 16.0161 mins ---
# Start 185
# None
# --- Completed 182, smoothened_receptor_antagonist, 16.0891 mins ---
# Start 186
# None
# --- Completed 183, sodium_channel_inhibitor, 16.8375 mins ---
# Start 187 None
#
# --- Completed 184, sphingosine_receptor_agonist, 16.2273 mins ---
# Start 188
# None
# --- Completed 185, src_inhibitor, 16.6016 mins ---
# Start 189
# None
# --- Completed 186, steroid, 14.9852 mins ---
# Start 190
# None
# --- Completed 187, syk_inhibitor, 15.2935 mins ---
# Start 191
# None
# --- Completed 188, tachykinin_antagonist, 15.7003 mins ---
# Start 192
# None
# --- Completed 189, tgf-beta_receptor_inhibitor, 15.2273 mins ---
# Start 193
# None
# --- Completed 190, thrombin_inhibitor, 15.4133 mins ---
# Start 194
# None
# --- Completed 191, thymidylate_synthase_inhibitor, 15.8758 mins ---
# Start 195
# None
# --- Completed 192, tlr_agonist, 15.4055 mins ---
# Start 196
# None
# --- Completed 193, tlr_antagonist, 14.6315 mins ---
# Start 197
# None
# --- Completed 194, tnf_inhibitor, 15.6109 mins ---
# Start 198
# None
# --- Completed 195, transient_receptor_potential_channel_antagonist, 14.9906 mins ---
# Start 199
# None
# --- Completed 196, topoisomerase_inhibitor, 17.1919 mins ---
# Start 200
# None
# --- Completed 197, tropomyosin_receptor_kinase_inhibitor, 14.8992 mins ---
# Start 201 None
#
# --- Completed 198, trpv_agonist, 16.3341 mins ---
# Start 202
# None
# --- Completed 199, trpv_antagonist, 16.2820 mins ---
# Start 203
# None
# --- Completed 200, tubulin_inhibitor, 16.9240 mins ---
# Start 204
# None
# --- Completed 201, tyrosine_kinase_inhibitor, 17.1276 mins ---
# Start 205 None
#
# --- Completed 202, ubiquitin_specific_protease_inhibitor, 15.5521 mins ---
# Start 206
# None
# --- Completed 203, vegfr_inhibitor, 16.7440 mins ---
# None
# --- Completed 204, vitamin_b, 15.1190 mins ---
# None
# --- Completed 205, vitamin_d_receptor_agonist, 13.8068 mins ---
# None
# --- Completed 206, wnt_inhibitor, 10.8471 mins ---
# None

# %%
best_params
# Out:
# {'5-alpha_reductase_inhibitor': {'class_weight': {0: 1, 1: 971},
#   'max_depth': 3,
#   'max_features': 25},
#  '11-beta-hsd1_inhibitor': {'class_weight': {0: 1, 1: 1214},
#   'max_depth': 3,
#   'max_features': 25},
#  'acat_inhibitor': {'class_weight': {0: 1, 1: 728},
#   'max_depth': 3,
#   'max_features': 25},
#  'acetylcholine_receptor_agonist': {'class_weight': {0: 1, 1: 95},
#   'max_depth': 4,
#   'max_features': 25},
#  'acetylcholinesterase_inhibitor': {'class_weight': {0: 1, 1: 255},
#   'max_depth': 3,
#   'max_features': 25},
#  'acetylcholine_receptor_antagonist': {'class_weight': {0: 1, 1: 59},
#   'max_depth': 3,
#   'max_features': 30},
#  'adenosine_receptor_agonist': {'class_weight': {0: 1, 1: 310},
#   'max_depth': 3,
#   'max_features': 25},
#  'adenosine_receptor_antagonist': {'class_weight': {0: 1, 1: 179},
#   'max_depth': 3,
#   'max_features': 25},
#  'adenylyl_cyclase_activator': {'class_weight': {0: 1, 1: 1457},
#   'max_depth': 3,
#   'max_features': 25},
#  'adrenergic_receptor_agonist': {'class_weight': {0: 1, 1: 67},
#   'max_depth': 3,
#   'max_features': 25},
#  'adrenergic_receptor_antagonist': {'class_weight': {0: 1, 1: 49},
#   'max_depth': 4,
#   'max_features': 25},
#  'akt_inhibitor': {'class_weight': {0: 1, 1: 264},
#   'max_depth': 3,
#   'max_features': 25},
#  'aldehyde_dehydrogenase_inhibitor': {'class_weight': {0: 1, 1: 2429},
#   'max_depth': 3,
#   'max_features': 25},
#  'alk_inhibitor': {'class_weight': {0: 1, 1: 378},
#   'max_depth': 3,
#   'max_features': 30},
#  'ampk_activator': {'class_weight': {0: 1, 1: 1457},
#   'max_depth': 3,
#   'max_features': 25},
#  'analgesic': {'class_weight': {0: 1, 1: 1619},
#   'max_depth': 3,
#   'max_features': 25},
#  'androgen_receptor_agonist': {'class_weight': {0: 1, 1: 330},
#   'max_depth': 3,
#   'max_features': 25},
#  'androgen_receptor_antagonist': {'class_weight': {0: 1, 1: 189},
#   'max_depth': 3,
#   'max_features': 25},
#  'anesthetic_-_local': {'class_weight': {0: 1, 1: 202},
#   'max_depth': 3,
#   'max_features': 25},
#  'angiogenesis_inhibitor': {'class_weight': {0: 1, 1: 455},
#   'max_depth': 3,
#   'max_features': 25},
#  'angiotensin_receptor_antagonist': {'class_weight': {0: 1, 1: 469},
#   'max_depth': 3,
#   'max_features': 25},
#  'anti-inflammatory': {'class_weight': {0: 1, 1: 242},
#   'max_depth': 3,
#   'max_features': 25},
#  'antiarrhythmic': {'class_weight': {0: 1, 1: 4857},
#   'max_depth': 3,
#   'max_features': 25},
#  'antibiotic': {'class_weight': {0: 1, 1: 433},
#   'max_depth': 3,
#   'max_features': 25},
#  'anticonvulsant': {'class_weight': {0: 1, 1: 1324},
#   'max_depth': 3,
#   'max_features': 25},
#  'antifungal': {'class_weight': {0: 1, 1: 1214},
#   'max_depth': 3,
#   'max_features': 25},
#  'antihistamine': {'class_weight': {0: 1, 1: 1619},
#   'max_depth': 3,
#   'max_features': 25},
#  'antimalarial': {'class_weight': {0: 1, 1: 910},
#   'max_depth': 3,
#   'max_features': 25},
#  'antioxidant': {'class_weight': {0: 1, 1: 234},
#   'max_depth': 3,
#   'max_features': 25},
#  'antiprotozoal': {'class_weight': {0: 1, 1: 520},
#   'max_depth': 3,
#   'max_features': 25},
#  'antiviral': {'class_weight': {0: 1, 1: 693},
#   'max_depth': 3,
#   'max_features': 25},
#  'apoptosis_stimulant': {'class_weight': {0: 1, 1: 323},
#   'max_depth': 3,
#   'max_features': 25},
#  'aromatase_inhibitor': {'class_weight': {0: 1, 1: 373},
#   'max_depth': 3,
#   'max_features': 25},
#  'atm_kinase_inhibitor': {'class_weight': {0: 1, 1: 2914},
#   'max_depth': 3,
#   'max_features': 25},
#  'atp-sensitive_potassium_channel_antagonist': {'class_weight': {0: 1,
#    1: 14574},
#   'max_depth': 3,
#   'max_features': 25},
#  'atp_synthase_inhibitor': {'class_weight': {0: 1, 1: 1457},
#   'max_depth': 3,
#   'max_features': 25},
#  'atr_kinase_inhibitor': {'class_weight': {0: 1, 1: 923},
#   'max_depth': 3,
#   'max_features': 30},
#  'atpase_inhibitor': {'class_weight': {0: 1, 1: 191},
#   'max_depth': 5,
#   'max_features': 30},
#  'aurora_kinase_inhibitor': {'class_weight': {0: 1, 1: 174},
#   'max_depth': 5,
#   'max_features': 25},
#  'autotaxin_inhibitor': {'class_weight': {0: 1, 1: 2914},
#   'max_depth': 3,
#   'max_features': 25},
#  'bacterial_30s_ribosomal_subunit_inhibitor': {'class_weight': {0: 1, 1: 279},
#   'max_depth': 3,
#   'max_features': 25},
#  'bacterial_50s_ribosomal_subunit_inhibitor': {'class_weight': {0: 1, 1: 227},
#   'max_depth': 3,
#   'max_features': 25},
#  'bacterial_antifolate': {'class_weight': {0: 1, 1: 469},
#   'max_depth': 3,
#   'max_features': 25},
#  'bacterial_cell_wall_synthesis_inhibitor': {'class_weight': {0: 1, 1: 94},
#   'max_depth': 3,
#   'max_features': 30},
#  'bacterial_dna_gyrase_inhibitor': {'class_weight': {0: 1, 1: 186},
#   'max_depth': 3,
#   'max_features': 25},
#  'bacterial_membrane_integrity_inhibitor': {'class_weight': {0: 1, 1: 2914},
#   'max_depth': 3,
#   'max_features': 25},
#  'bacterial_dna_inhibitor': {'class_weight': {0: 1, 1: 138},
#   'max_depth': 3,
#   'max_features': 25},
#  'bcl_inhibitor': {'class_weight': {0: 1, 1: 542},
#   'max_depth': 3,
#   'max_features': 30},
#  'bcr-abl_inhibitor': {'class_weight': {0: 1, 1: 455},
#   'max_depth': 3,
#   'max_features': 30},
#  'beta_amyloid_inhibitor': {'class_weight': {0: 1, 1: 857},
#   'max_depth': 3,
#   'max_features': 25},
#  'benzodiazepine_receptor_agonist': {'class_weight': {0: 1, 1: 234},
#   'max_depth': 3,
#   'max_features': 25},
#  'bromodomain_inhibitor': {'class_weight': {0: 1, 1: 264},
#   'max_depth': 5,
#   'max_features': 25},
#  'btk_inhibitor': {'class_weight': {0: 1, 1: 606},
#   'max_depth': 3,
#   'max_features': 25},
#  'calcineurin_inhibitor': {'class_weight': {0: 1, 1: 2429},
#   'max_depth': 3,
#   'max_features': 25},
#  'calcium_channel_blocker': {'class_weight': {0: 1, 1: 60},
#   'max_depth': 4,
#   'max_features': 25},
#  'cannabinoid_receptor_agonist': {'class_weight': {0: 1, 1: 364},
#   'max_depth': 3,
#   'max_features': 25},
#  'cannabinoid_receptor_antagonist': {'class_weight': {0: 1, 1: 303},
#   'max_depth': 3,
#   'max_features': 25},
#  'carbonic_anhydrase_inhibitor': {'class_weight': {0: 1, 1: 469},
#   'max_depth': 3,
#   'max_features': 25},
#  'casein_kinase_inhibitor': {'class_weight': {0: 1, 1: 520},
#   'max_depth': 3,
#   'max_features': 25},
#  'caspase_activator': {'class_weight': {0: 1, 1: 857},
#   'max_depth': 3,
#   'max_features': 25},
#  'catechol_o_methyltransferase_inhibitor': {'class_weight': {0: 1, 1: 1457},
#   'max_depth': 3,
#   'max_features': 25},
#  'cc_chemokine_receptor_antagonist': {'class_weight': {0: 1, 1: 161},
#   'max_depth': 3,
#   'max_features': 25},
#  'cck_receptor_antagonist': {'class_weight': {0: 1, 1: 809},
#   'max_depth': 3,
#   'max_features': 25},
#  'cdk_inhibitor': {'class_weight': {0: 1, 1: 50},
#   'max_depth': 6,
#   'max_features': 30},
#  'chelating_agent': {'class_weight': {0: 1, 1: 310},
#   'max_depth': 3,
#   'max_features': 25},
#  'chk_inhibitor': {'class_weight': {0: 1, 1: 809},
#   'max_depth': 3,
#   'max_features': 30},
#  'chloride_channel_blocker': {'class_weight': {0: 1, 1: 373},
#   'max_depth': 3,
#   'max_features': 25},
#  'cholesterol_inhibitor': {'class_weight': {0: 1, 1: 330},
#   'max_depth': 3,
#   'max_features': 25},
#  'cholinergic_receptor_antagonist': {'class_weight': {0: 1, 1: 310},
#   'max_depth': 3,
#   'max_features': 25},
#  'coagulation_factor_inhibitor': {'class_weight': {0: 1, 1: 3643},
#   'max_depth': 3,
#   'max_features': 25},
#  'corticosteroid_agonist': {'class_weight': {0: 1, 1: 482},
#   'max_depth': 3,
#   'max_features': 25},
#  'cytochrome_p450_inhibitor': {'class_weight': {0: 1, 1: 167},
#   'max_depth': 3,
#   'max_features': 25},
#  'dihydrofolate_reductase_inhibitor': {'class_weight': {0: 1, 1: 485},
#   'max_depth': 3,
#   'max_features': 30},
#  'cyclooxygenase_inhibitor': {'class_weight': {0: 1, 1: 43},
#   'max_depth': 3,
#   'max_features': 25},
#  'dipeptidyl_peptidase_inhibitor': {'class_weight': {0: 1, 1: 633},
#   'max_depth': 3,
#   'max_features': 25},
#  'diuretic': {'class_weight': {0: 1, 1: 2429},
#   'max_depth': 3,
#   'max_features': 25},
#  'dna_alkylating_agent': {'class_weight': {0: 1, 1: 373},
#   'max_depth': 3,
#   'max_features': 25},
#  'dna_inhibitor': {'class_weight': {0: 1, 1: 42},
#   'max_depth': 3,
#   'max_features': 30},
#  'dopamine_receptor_agonist': {'class_weight': {0: 1, 1: 138},
#   'max_depth': 3,
#   'max_features': 25},
#  'dopamine_receptor_antagonist': {'class_weight': {0: 1, 1: 41},
#   'max_depth': 5,
#   'max_features': 30},
#  'elastase_inhibitor': {'class_weight': {0: 1, 1: 4857},
#   'max_depth': 3,
#   'max_features': 25},
#  'erbb2_inhibitor': {'class_weight': {0: 1, 1: 14574},
#   'max_depth': 3,
#   'max_features': 25},
#  'egfr_inhibitor': {'class_weight': {0: 1, 1: 53},
#   'max_depth': 6,
#   'max_features': 30},
#  'estrogen_receptor_agonist': {'class_weight': {0: 1, 1: 106},
#   'max_depth': 4,
#   'max_features': 30},
#  'farnesyltransferase_inhibitor': {'class_weight': {0: 1, 1: 809},
#   'max_depth': 3,
#   'max_features': 25},
#  'estrogen_receptor_antagonist': {'class_weight': {0: 1, 1: 428},
#   'max_depth': 3,
#   'max_features': 25},
#  'faah_inhibitor': {'class_weight': {0: 1, 1: 469},
#   'max_depth': 3,
#   'max_features': 25},
#  'fatty_acid_receptor_agonist': {'class_weight': {0: 1, 1: 693},
#   'max_depth': 3,
#   'max_features': 25},
#  'focal_adhesion_kinase_inhibitor': {'class_weight': {0: 1, 1: 971},
#   'max_depth': 3,
#   'max_features': 30},
#  'fgfr_inhibitor': {'class_weight': {0: 1, 1: 364},
#   'max_depth': 3,
#   'max_features': 25},
#  'flt3_inhibitor': {'class_weight': {0: 1, 1: 64},
#   'max_depth': 4,
#   'max_features': 30},
#  'free_radical_scavenger': {'class_weight': {0: 1, 1: 910},
#   'max_depth': 3,
#   'max_features': 25},
#  'fungal_squalene_epoxidase_inhibitor': {'class_weight': {0: 1, 1: 809},
#   'max_depth': 3,
#   'max_features': 25},
#  'gaba_receptor_agonist': {'class_weight': {0: 1, 1: 165},
#   'max_depth': 3,
#   'max_features': 25},
#  'gaba_receptor_antagonist': {'class_weight': {0: 1, 1: 114},
#   'max_depth': 3,
#   'max_features': 25},
#  'gamma_secretase_inhibitor': {'class_weight': {0: 1, 1: 349},
#   'max_depth': 3,
#   'max_features': 25},
#  'glutamate_inhibitor': {'class_weight': {0: 1, 1: 1324},
#   'max_depth': 3,
#   'max_features': 25},
#  'glucocorticoid_receptor_agonist': {'class_weight': {0: 1, 1: 66},
#   'max_depth': 6,
#   'max_features': 25},
#  'glutamate_receptor_agonist': {'class_weight': {0: 1, 1: 238},
#   'max_depth': 3,
#   'max_features': 25},
#  'glutamate_receptor_antagonist': {'class_weight': {0: 1, 1: 51},
#   'max_depth': 4,
#   'max_features': 30},
#  'gonadotropin_receptor_agonist': {'class_weight': {0: 1, 1: 857},
#   'max_depth': 3,
#   'max_features': 25},
#  'gsk_inhibitor': {'class_weight': {0: 1, 1: 297},
#   'max_depth': 3,
#   'max_features': 30},
#  'hcv_inhibitor': {'class_weight': {0: 1, 1: 238},
#   'max_depth': 3,
#   'max_features': 25},
#  'hdac_inhibitor': {'class_weight': {0: 1, 1: 158},
#   'max_depth': 3,
#   'max_features': 30},
#  'histamine_receptor_agonist': {'class_weight': {0: 1, 1: 297},
#   'max_depth': 3,
#   'max_features': 25},
#  'histamine_receptor_antagonist': {'class_weight': {0: 1, 1: 71},
#   'max_depth': 4,
#   'max_features': 30},
#  'histone_lysine_demethylase_inhibitor': {'class_weight': {0: 1, 1: 728},
#   'max_depth': 3,
#   'max_features': 25},
#  'histone_lysine_methyltransferase_inhibitor': {'class_weight': {0: 1, 1: 520},
#   'max_depth': 3,
#   'max_features': 25},
#  'hiv_inhibitor': {'class_weight': {0: 1, 1: 223},
#   'max_depth': 3,
#   'max_features': 25},
#  'hmgcr_inhibitor': {'class_weight': {0: 1, 1: 61},
#   'max_depth': 5,
#   'max_features': 30},
#  'hsp_inhibitor': {'class_weight': {0: 1, 1: 201},
#   'max_depth': 3,
#   'max_features': 25},
#  'igf-1_inhibitor': {'class_weight': {0: 1, 1: 489},
#   'max_depth': 3,
#   'max_features': 30},
#  'ikk_inhibitor': {'class_weight': {0: 1, 1: 509},
#   'max_depth': 3,
#   'max_features': 30},
#  'imidazoline_receptor_agonist': {'class_weight': {0: 1, 1: 485},
#   'max_depth': 3,
#   'max_features': 25},
#  'immunosuppressant': {'class_weight': {0: 1, 1: 245},
#   'max_depth': 3,
#   'max_features': 25},
#  'insulin_secretagogue': {'class_weight': {0: 1, 1: 606},
#   'max_depth': 3,
#   'max_features': 25},
#  'insulin_sensitizer': {'class_weight': {0: 1, 1: 393},
#   'max_depth': 3,
#   'max_features': 30},
#  'integrin_inhibitor': {'class_weight': {0: 1, 1: 383},
#   'max_depth': 3,
#   'max_features': 25},
#  'jak_inhibitor': {'class_weight': {0: 1, 1: 187},
#   'max_depth': 3,
#   'max_features': 30},
#  'kit_inhibitor': {'class_weight': {0: 1, 1: 65},
#   'max_depth': 4,
#   'max_features': 25},
#  'laxative': {'class_weight': {0: 1, 1: 2914},
#   'max_depth': 3,
#   'max_features': 25},
#  'leukotriene_inhibitor': {'class_weight': {0: 1, 1: 4857},
#   'max_depth': 3,
#   'max_features': 25},
#  'leukotriene_receptor_antagonist': {'class_weight': {0: 1, 1: 303},
#   'max_depth': 3,
#   'max_features': 25},
#  'lipase_inhibitor': {'class_weight': {0: 1, 1: 2429},
#   'max_depth': 3,
#   'max_features': 25},
#  'lipoxygenase_inhibitor': {'class_weight': {0: 1, 1: 297},
#   'max_depth': 3,
#   'max_features': 25},
#  'lxr_agonist': {'class_weight': {0: 1, 1: 2914},
#   'max_depth': 3,
#   'max_features': 25},
#  'mdm_inhibitor': {'class_weight': {0: 1, 1: 582},
#   'max_depth': 3,
#   'max_features': 25},
#  'mek_inhibitor': {'class_weight': {0: 1, 1: 252},
#   'max_depth': 6,
#   'max_features': 30},
#  'membrane_integrity_inhibitor': {'class_weight': {0: 1, 1: 274},
#   'max_depth': 3,
#   'max_features': 25},
#  'mineralocorticoid_receptor_antagonist': {'class_weight': {0: 1, 1: 728},
#   'max_depth': 3,
#   'max_features': 25},
#  'monoacylglycerol_lipase_inhibitor': {'class_weight': {0: 1, 1: 1214},
#   'max_depth': 3,
#   'max_features': 25},
#  'monoamine_oxidase_inhibitor': {'class_weight': {0: 1, 1: 191},
#   'max_depth': 3,
#   'max_features': 30},
#  'monopolar_spindle_1_kinase_inhibitor': {'class_weight': {0: 1, 1: 910},
#   'max_depth': 3,
#   'max_features': 25},
#  'mtor_inhibitor': {'class_weight': {0: 1, 1: 137},
#   'max_depth': 4,
#   'max_features': 25},
#  'mucolytic_agent': {'class_weight': {0: 1, 1: 330},
#   'max_depth': 3,
#   'max_features': 25},
#  'neuropeptide_receptor_antagonist': {'class_weight': {0: 1, 1: 415},
#   'max_depth': 3,
#   'max_features': 25},
#  'nfkb_inhibitor': {'class_weight': {0: 1, 1: 20},
#   'max_depth': 6,
#   'max_features': 30},
#  'nicotinic_receptor_agonist': {'class_weight': {0: 1, 1: 3643},
#   'max_depth': 3,
#   'max_features': 25},
#  'nitric_oxide_donor': {'class_weight': {0: 1, 1: 633},
#   'max_depth': 3,
#   'max_features': 25},
#  'nitric_oxide_production_inhibitor': {'class_weight': {0: 1, 1: 1214},
#   'max_depth': 3,
#   'max_features': 25},
#  'nitric_oxide_synthase_inhibitor': {'class_weight': {0: 1, 1: 633},
#   'max_depth': 3,
#   'max_features': 25},
#  'norepinephrine_reuptake_inhibitor': {'class_weight': {0: 1, 1: 3643},
#   'max_depth': 3,
#   'max_features': 25},
#  'nrf2_activator': {'class_weight': {0: 1, 1: 892},
#   'max_depth': 3,
#   'max_features': 25},
#  'opioid_receptor_agonist': {'class_weight': {0: 1, 1: 291},
#   'max_depth': 3,
#   'max_features': 25},
#  'opioid_receptor_antagonist': {'class_weight': {0: 1, 1: 175},
#   'max_depth': 3,
#   'max_features': 25},
#  'orexin_receptor_antagonist': {'class_weight': {0: 1, 1: 455},
#   'max_depth': 3,
#   'max_features': 25},
#  'p-glycoprotein_inhibitor': {'class_weight': {0: 1, 1: 766},
#   'max_depth': 3,
#   'max_features': 25},
#  'p38_mapk_inhibitor': {'class_weight': {0: 1, 1: 287},
#   'max_depth': 3,
#   'max_features': 25},
#  'parp_inhibitor': {'class_weight': {0: 1, 1: 255},
#   'max_depth': 3,
#   'max_features': 25},
#  'pdgfr_inhibitor': {'class_weight': {0: 1, 1: 59},
#   'max_depth': 4,
#   'max_features': 25},
#  'pdk_inhibitor': {'class_weight': {0: 1, 1: 1040},
#   'max_depth': 3,
#   'max_features': 25},
#  'phosphodiesterase_inhibitor': {'class_weight': {0: 1, 1: 63},
#   'max_depth': 5,
#   'max_features': 30},
#  'phospholipase_inhibitor': {'class_weight': {0: 1, 1: 809},
#   'max_depth': 3,
#   'max_features': 25},
#  'pi3k_inhibitor': {'class_weight': {0: 1, 1: 112},
#   'max_depth': 5,
#   'max_features': 30},
#  'pkc_inhibitor': {'class_weight': {0: 1, 1: 728},
#   'max_depth': 3,
#   'max_features': 25},
#  'potassium_channel_activator': {'class_weight': {0: 1, 1: 373},
#   'max_depth': 3,
#   'max_features': 25},
#  'potassium_channel_antagonist': {'class_weight': {0: 1, 1: 168},
#   'max_depth': 3,
#   'max_features': 25},
#  'ppar_receptor_agonist': {'class_weight': {0: 1, 1: 154},
#   'max_depth': 3,
#   'max_features': 30},
#  'ppar_receptor_antagonist': {'class_weight': {0: 1, 1: 539},
#   'max_depth': 3,
#   'max_features': 25},
#  'progesterone_receptor_agonist': {'class_weight': {0: 1, 1: 150},
#   'max_depth': 4,
#   'max_features': 30},
#  'progesterone_receptor_antagonist': {'class_weight': {0: 1, 1: 971},
#   'max_depth': 3,
#   'max_features': 25},
#  'prostaglandin_inhibitor': {'class_weight': {0: 1, 1: 455},
#   'max_depth': 3,
#   'max_features': 25},
#  'prostanoid_receptor_antagonist': {'class_weight': {0: 1, 1: 199},
#   'max_depth': 3,
#   'max_features': 25},
#  'proteasome_inhibitor': {'class_weight': {0: 1, 1: 24},
#   'max_depth': 6,
#   'max_features': 30},
#  'protein_kinase_inhibitor': {'class_weight': {0: 1, 1: 393},
#   'max_depth': 3,
#   'max_features': 25},
#  'protein_phosphatase_inhibitor': {'class_weight': {0: 1, 1: 2914},
#   'max_depth': 3,
#   'max_features': 25},
#  'protein_synthesis_inhibitor': {'class_weight': {0: 1, 1: 154},
#   'max_depth': 3,
#   'max_features': 30},
#  'protein_tyrosine_kinase_inhibitor': {'class_weight': {0: 1, 1: 1214},
#   'max_depth': 3,
#   'max_features': 25},
#  'radiopaque_medium': {'class_weight': {0: 1, 1: 310},
#   'max_depth': 3,
#   'max_features': 25},
#  'raf_inhibitor': {'class_weight': {0: 1, 1: 74},
#   'max_depth': 6,
#   'max_features': 30},
#  'ras_gtpase_inhibitor': {'class_weight': {0: 1, 1: 1619},
#   'max_depth': 3,
#   'max_features': 25},
#  'retinoid_receptor_agonist': {'class_weight': {0: 1, 1: 279},
#   'max_depth': 3,
#   'max_features': 30},
#  'retinoid_receptor_antagonist': {'class_weight': {0: 1, 1: 7286},
#   'max_depth': 3,
#   'max_features': 25},
#  'rho_associated_kinase_inhibitor': {'class_weight': {0: 1, 1: 485},
#   'max_depth': 3,
#   'max_features': 25},
#  'ribonucleoside_reductase_inhibitor': {'class_weight': {0: 1, 1: 499},
#   'max_depth': 3,
#   'max_features': 30},
#  'rna_polymerase_inhibitor': {'class_weight': {0: 1, 1: 662},
#   'max_depth': 3,
#   'max_features': 25},
#  'serotonin_receptor_agonist': {'class_weight': {0: 1, 1: 72},
#   'max_depth': 3,
#   'max_features': 25},
#  'serotonin_receptor_antagonist': {'class_weight': {0: 1, 1: 41},
#   'max_depth': 4,
#   'max_features': 25},
#  'serotonin_reuptake_inhibitor': {'class_weight': {0: 1, 1: 393},
#   'max_depth': 3,
#   'max_features': 25},
#  'sigma_receptor_agonist': {'class_weight': {0: 1, 1: 455},
#   'max_depth': 3,
#   'max_features': 25},
#  'sigma_receptor_antagonist': {'class_weight': {0: 1, 1: 502},
#   'max_depth': 3,
#   'max_features': 25},
#  'smoothened_receptor_antagonist': {'class_weight': {0: 1, 1: 693},
#   'max_depth': 3,
#   'max_features': 25},
#  'sodium_channel_inhibitor': {'class_weight': {0: 1, 1: 69},
#   'max_depth': 4,
#   'max_features': 25},
#  'sphingosine_receptor_agonist': {'class_weight': {0: 1, 1: 766},
#   'max_depth': 3,
#   'max_features': 25},
#  'src_inhibitor': {'class_weight': {0: 1, 1: 214},
#   'max_depth': 4,
#   'max_features': 25},
#  'steroid': {'class_weight': {0: 1, 1: 2914},
#   'max_depth': 3,
#   'max_features': 25},
#  'syk_inhibitor': {'class_weight': {0: 1, 1: 857},
#   'max_depth': 3,
#   'max_features': 25},
#  'tachykinin_antagonist': {'class_weight': {0: 1, 1: 264},
#   'max_depth': 3,
#   'max_features': 25},
#  'tgf-beta_receptor_inhibitor': {'class_weight': {0: 1, 1: 662},
#   'max_depth': 3,
#   'max_features': 30},
#  'thrombin_inhibitor': {'class_weight': {0: 1, 1: 857},
#   'max_depth': 3,
#   'max_features': 25},
#  'thymidylate_synthase_inhibitor': {'class_weight': {0: 1, 1: 455},
#   'max_depth': 3,
#   'max_features': 25},
#  'tlr_agonist': {'class_weight': {0: 1, 1: 520},
#   'max_depth': 3,
#   'max_features': 25},
#  'tlr_antagonist': {'class_weight': {0: 1, 1: 2914},
#   'max_depth': 3,
#   'max_features': 25},
#  'tnf_inhibitor': {'class_weight': {0: 1, 1: 415},
#   'max_depth': 3,
#   'max_features': 25},
#  'transient_receptor_potential_channel_antagonist': {'class_weight': {0: 1,
#    1: 857},
#   'max_depth': 3,
#   'max_features': 25},
#  'topoisomerase_inhibitor': {'class_weight': {0: 1, 1: 137},
#   'max_depth': 6,
#   'max_features': 30},
#  'tropomyosin_receptor_kinase_inhibitor': {'class_weight': {0: 1, 1: 2429},
#   'max_depth': 3,
#   'max_features': 25},
#  'trpv_agonist': {'class_weight': {0: 1, 1: 662},
#   'max_depth': 3,
#   'max_features': 25},
#  'trpv_antagonist': {'class_weight': {0: 1, 1: 338},
#   'max_depth': 3,
#   'max_features': 25},
#  'tubulin_inhibitor': {'class_weight': {0: 1, 1: 53},
#   'max_depth': 6,
#   'max_features': 30},
#  'tyrosine_kinase_inhibitor': {'class_weight': {0: 1, 1: 248},
#   'max_depth': 4,
#   'max_features': 25},
#  'ubiquitin_specific_protease_inhibitor': {'class_weight': {0: 1, 1: 2914},
#   'max_depth': 3,
#   'max_features': 25},
#  'vegfr_inhibitor': {'class_weight': {0: 1, 1: 104},
#   'max_depth': 3,
#   'max_features': 25},
#  'vitamin_b': {'class_weight': {0: 1, 1: 693},
#   'max_depth': 3,
#   'max_features': 25},
#  'vitamin_d_receptor_agonist': {'class_weight': {0: 1, 1: 441},
#   'max_depth': 3,
#   'max_features': 25},
#  'wnt_inhibitor': {'class_weight': {0: 1, 1: 520},
#   'max_depth': 3,
#   'max_features': 25}}

# %%
# load saved models
best_rfc = {}
for i, col_name in enumerate(y_train.columns):
    try:
        best_rfc[col_name] = joblib.load(f'./TrainedModels/RandForest/logloss/rf_{i}.joblib')
    except:
        print(f'rfc_{i}.joblib does not exist.')
# Out:
# rfc_22.joblib does not exist.
# rfc_34.joblib does not exist.
# rfc_69.joblib does not exist.
# rfc_81.joblib does not exist.
# rfc_82.joblib does not exist.
# rfc_121.joblib does not exist.
# rfc_137.joblib does not exist.
# rfc_141.joblib does not exist.
# rfc_172.joblib does not exist.

# %%
# inference - training
y_train_pred = np.zeros(y_train.shape).astype('float')
y_train_pred_proba = np.zeros(y_train.shape).astype('float')
for i, col_name in tqdm(enumerate(y_train.columns)):
    rfc = best_rfc.get(col_name, None)
    if rfc!=None:
        y_train_pred[:,i] = rfc.predict(X_train)
        y_train_pred_proba[:,i] = rfc.predict_proba(X_train)[:,1]
# Out:
# 206it [04:05,  1.19s/it]

# %%
# overall log_loss
print(log_loss(y_train.values.reshape(-1, 1), y_train_pred_proba.reshape(-1,1)))
# overall precision
print(precision_score(y_train.values.reshape(-1, 1), y_train_pred.reshape(-1,1)))
# overall precision
print(recall_score(y_train.values.reshape(-1, 1), y_train_pred.reshape(-1,1)))
# Out:
# 0.05924467548877927
# 0.9286071965090493
# 0.9068743887103535

# %%
# inference - test
y_pred = np.zeros(y_test.shape).astype('float')
y_pred_proba = np.zeros(y_test.shape).astype('float')
for i, col_name in tqdm(enumerate(y_test.columns)):
    rfc = best_rfc.get(col_name, None)
    if rfc!=None:
        y_pred[:,i] = rfc.predict(X_test)
        y_pred_proba[:,i] = rfc.predict_proba(X_test)[:,1]
# Out:
# 206it [00:49,  4.14it/s]

# %%
# overall log_loss
print(log_loss(y_test.values.reshape(-1, 1), y_pred_proba.reshape(-1,1)))
# overall precision
print(precision_score(y_test.values.reshape(-1, 1), y_pred.reshape(-1,1)))
# overall precision
print(recall_score(y_test.values.reshape(-1, 1), y_pred.reshape(-1,1)))
# Out:
# 0.06704424027108556
# 0.7223001402524544
# 0.20355731225296442

# %%
# recall, f1, for each column
recall = np.zeros(y_train.shape[1])
f1 = np.zeros(y_train.shape[1])
for i in range(y_pred.shape[1]):
    recall[i] = recall_score(y_test.values[:,i], y_pred[:,i])
    f1[i] = f1_score(y_test.values[:,i], y_pred[:,i])
    
# best weight_ratio
ratio = np.zeros(y_train.shape[1])
# weight_ratio = np.ones(y_train.shape[1])*0.72
for i, (col_name, y) in enumerate(y_train.iteritems()):
    ratio[i] = round(len(y)/sum(y)-1)
#     rfc = best_rfc.get(col_name, None)
#     if rfc != None:
#         param = rfc.params_
#         weight_ratio[i] = round(param['class_weight'][1]/ratio[i], 2)

# %%
f1[f1>0.8]
# Out:
# array([0.84931507, 0.90322581, 0.87452471, 0.94262295, 0.88135593])

# %%
np.where(f1>0.9)
# Out:
# (array([110, 163], dtype=int64),)

# %%
plt.figure(figsize=(15, 6))
# plt.plot(ratio)
plt.plot(recall)

# %%
weight_ratio[recall==0]

# %%
ratio[recall==0]

# %% [markdown]
# ### Submission

# %%
df_submit = pd.read_csv(data_dir+'test_features.csv', index_col='sig_id')
df_submit['cp_type'].replace({'trt_cp':1., 'ctl_vehicle':0.}, inplace=True)
df_submit['cp_dose'].replace({'D1':1., 'D2':0.}, inplace=True)
df_submit.head()

# inference
y_submit_pred_proba = np.zeros((df_submit.shape[0], y_test.shape[1])).astype('float')
for i, col_name in tqdm(enumerate(y_train.columns)):
    rfc = best_rfc.get(col_name, None)
    if rfc!=None:
        y_submit_pred_proba[:,i] = rfc.predict_proba(df_submit)[:,1]
        
y_submit_proba = pd.DataFrame(y_submit_pred_proba)
y_submit_proba.index = df_submit.index
y_submit_proba.columns = y_train.columns
y_submit_proba.head()

y_submit_proba.to_csv('submission.csv')
# Out:
# 206it [10:32,  3.07s/it]
